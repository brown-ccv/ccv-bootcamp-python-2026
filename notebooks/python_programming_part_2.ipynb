# %%
# Setup Cell: Run this to pull the workshop data files into Colab
import os

if os.path.exists('ccv-bootcamp-python-2026'):
  # !rm -rf /content/ccv-bootcamp-python-2026
# !git clone --quiet https://github.com/brown-ccv/ccv-bootcamp-python-2026.git
print("✅ Workshop data successfully loaded!")

# %% [markdown]
# # Intro to Python Programming II: Packages, Environments, Tabular Data
#
# Most of this lecture will be presented through slides. This notebook will be used interactively for you to try out examples and perform exercises.
#
# ---
#
# ## How to use the notebook
# 1.   There are code cells and text cells.
# 2.   Execute code cells by pressing the play button ▶️ at the top left of the cell or `shift` + `enter`
# 3.   Cells can be run in any order, but it is best practice to execute from top to bottom.
# 4.   To start, run the setup code cell below to pull the workshop data files into Colab.

# %%
import pandas as pd

# %%
df_data = pd.read_csv('../data/processed/combined_file.csv')

# %%
df_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 33850 entries, 0 to 33849
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   State Code                  33850 non-null  int64
#  1   County Code                 33850 non-null  int64
#  2   Site Number                 33850 non-null  int64
#  3   Parameter Code              33850 non-null  int64
#  4   POC                         33850 non-null  int64
#  5   Latitude                    33850 non-null  float64
#  6   Longitude                   33850 non-null  float64
#  7   Datum                       33850 non-null  str
#  8   Parameter Name              33850 non-null  str
#  9   Duration Description        33850 non-null  str
#  10  Pollutant Standard          3279 non-null   str
#  11  Date (Local)                33850 non-null  str
#  12  Year                        33850 non-null  int64
#  13  Day In Year (Local)         33850 non-null  int64
#  14  Units of Measure            33850 non-null  str
#  15  Exceptional Data Type       0 non-null      float64
#  16  Nonreg Observation Count    0 non-null      float64
#  17  Observation Count           33850 non-null  int64
#  18  Observation Percent         33850 non-null  float64
#  19  Nonreg Arithmetic Mean      0 non-null      float64
#  20  Arithmetic Mean             33850 non-null  float64
#  21  Nonreg First Maximum Value  0 non-null      float64
#  22  First Maximum Value         33850 non-null  float64
#  23  First Maximum Hour          33850 non-null  int64
#  24  AQI                         33850 non-null  str
#  25  Daily Criteria Indicator    33850 non-null  str
#  26  Tribe Name                  0 non-null      float64
#  27  State Name                  33850 non-null  str
#  28  County Name                 33850 non-null  str
#  29  City Name                   33850 non-null  str
#  30  Local Site Name             33850 non-null  str
#  31  Address                     33850 non-null  str
#  32  MSA or CBSA Name            33850 non-null  str
#  33  Data Source                 33850 non-null  str
# dtypes: float64(10), int64(9), str(15)
# memory usage: 8.8 MB

# %%
df_data.head(20)
# Out:
#     State Code  County Code  Site Number  Parameter Code  POC   Latitude  \
# 0           44            7           22           88101    3  41.807469
# 1           44            7           22           88101    3  41.807469
# 2           44            7           22           88101    3  41.807469
# 3           44            7           22           61104    1  41.807469
# 4           44            7           22           84313    1  41.807469
# 5           44            7           22           61107    1  41.807469
# 6           44            7           22           87101    1  41.807469
# 7           44            7           22           62201    1  41.807469
# 8           44            7           22           62101    1  41.807469
# 9           44            7           22           88101    3  41.807469
# 10          44            7           22           88101    3  41.807469
# 11          44            7           22           88101    3  41.807469
# 12          44            7           22           61104    1  41.807469
# 13          44            7           22           84313    1  41.807469
# 14          44            7           22           61107    1  41.807469
# 15          44            7           22           87101    1  41.807469
# 16          44            7           22           62201    1  41.807469
# 17          44            7           22           62101    1  41.807469
# 18          44            7           22           88101    3  41.807469
# 19          44            7           22           88101    3  41.807469
#
#     Longitude  Datum                Parameter Name Duration Description  ...  \
# 0  -71.412968  NAD83      PM2.5 - Local Conditions               1 HOUR  ...
# 1  -71.412968  NAD83      PM2.5 - Local Conditions        24-HR BLK AVG  ...
# 2  -71.412968  NAD83      PM2.5 - Local Conditions        24-HR BLK AVG  ...
# 3  -71.412968  NAD83    Wind Direction - Resultant               1 HOUR  ...
# 4  -71.412968  NAD83        Black carbon PM2.5 STP               1 HOUR  ...
# 5  -71.412968  NAD83     Std Dev Vt Wind Direction               1 HOUR  ...
# 6  -71.412968  NAD83  Particle Number, Total Count               1 HOUR  ...
# 7  -71.412968  NAD83             Relative Humidity               1 HOUR  ...
# 8  -71.412968  NAD83           Outdoor Temperature               1 HOUR  ...
# 9  -71.412968  NAD83      PM2.5 - Local Conditions               1 HOUR  ...
# 10 -71.412968  NAD83      PM2.5 - Local Conditions        24-HR BLK AVG  ...
# 11 -71.412968  NAD83      PM2.5 - Local Conditions        24-HR BLK AVG  ...
# 12 -71.412968  NAD83    Wind Direction - Resultant               1 HOUR  ...
# 13 -71.412968  NAD83        Black carbon PM2.5 STP               1 HOUR  ...
# 14 -71.412968  NAD83     Std Dev Vt Wind Direction               1 HOUR  ...
# 15 -71.412968  NAD83  Particle Number, Total Count               1 HOUR  ...
# 16 -71.412968  NAD83             Relative Humidity               1 HOUR  ...
# 17 -71.412968  NAD83           Outdoor Temperature               1 HOUR  ...
# 18 -71.412968  NAD83      PM2.5 - Local Conditions               1 HOUR  ...
# 19 -71.412968  NAD83      PM2.5 - Local Conditions        24-HR BLK AVG  ...
#
#    AQI Daily Criteria Indicator  Tribe Name    State Name County Name  \
# 0    .                        Y         NaN  Rhode Island  Providence
# 1   39                        Y         NaN  Rhode Island  Providence
# 2   39                        Y         NaN  Rhode Island  Providence
# 3    .                        Y         NaN  Rhode Island  Providence
# 4    .                        Y         NaN  Rhode Island  Providence
# 5    .                        Y         NaN  Rhode Island  Providence
# 6    .                        Y         NaN  Rhode Island  Providence
# 7    .                        Y         NaN  Rhode Island  Providence
# 8    .                        Y         NaN  Rhode Island  Providence
# 9    .                        Y         NaN  Rhode Island  Providence
# 10  17                        Y         NaN  Rhode Island  Providence
# 11  17                        Y         NaN  Rhode Island  Providence
# 12   .                        Y         NaN  Rhode Island  Providence
# 13   .                        Y         NaN  Rhode Island  Providence
# 14   .                        Y         NaN  Rhode Island  Providence
# 15   .                        Y         NaN  Rhode Island  Providence
# 16   .                        Y         NaN  Rhode Island  Providence
# 17   .                        Y         NaN  Rhode Island  Providence
# 18   .                        Y         NaN  Rhode Island  Providence
# 19  19                        Y         NaN  Rhode Island  Providence
#
#      City Name             Local Site Name                     Address  \
# 0   Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 1   Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 2   Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 3   Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 4   Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 5   Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 6   Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 7   Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 8   Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 9   Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 10  Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 11  Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 12  Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 13  Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 14  Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 15  Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 16  Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 17  Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 18  Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
# 19  Providence  CCRI Liston Campus ROOFTOP  1 Hilton St, PROVIDENCE RI
#
#              MSA or CBSA Name    Data Source
# 0   Providence-Warwick, RI-MA  AQS Data Mart
# 1   Providence-Warwick, RI-MA  AQS Data Mart
# 2   Providence-Warwick, RI-MA  AQS Data Mart
# 3   Providence-Warwick, RI-MA  AQS Data Mart
# 4   Providence-Warwick, RI-MA  AQS Data Mart
# 5   Providence-Warwick, RI-MA  AQS Data Mart
# 6   Providence-Warwick, RI-MA  AQS Data Mart
# 7   Providence-Warwick, RI-MA  AQS Data Mart
# 8   Providence-Warwick, RI-MA  AQS Data Mart
# 9   Providence-Warwick, RI-MA  AQS Data Mart
# 10  Providence-Warwick, RI-MA  AQS Data Mart
# 11  Providence-Warwick, RI-MA  AQS Data Mart
# 12  Providence-Warwick, RI-MA  AQS Data Mart
# 13  Providence-Warwick, RI-MA  AQS Data Mart
# 14  Providence-Warwick, RI-MA  AQS Data Mart
# 15  Providence-Warwick, RI-MA  AQS Data Mart
# 16  Providence-Warwick, RI-MA  AQS Data Mart
# 17  Providence-Warwick, RI-MA  AQS Data Mart
# 18  Providence-Warwick, RI-MA  AQS Data Mart
# 19  Providence-Warwick, RI-MA  AQS Data Mart
#
# [20 rows x 34 columns]

# %%
df_data[['State Name', 'County Name', 'City Name', 'Local Site Name', 'Address',
       'MSA or CBSA Name', 'Data Source']]
# Out:
#          State Name County Name   City Name             Local Site Name  \
# 0      Rhode Island  Providence  Providence  CCRI Liston Campus ROOFTOP
# 1      Rhode Island  Providence  Providence  CCRI Liston Campus ROOFTOP
# 2      Rhode Island  Providence  Providence  CCRI Liston Campus ROOFTOP
# 3      Rhode Island  Providence  Providence  CCRI Liston Campus ROOFTOP
# 4      Rhode Island  Providence  Providence  CCRI Liston Campus ROOFTOP
# ...             ...         ...         ...                         ...
# 33845  Rhode Island  Providence  Providence  CCRI Liston Campus ROOFTOP
# 33846  Rhode Island  Providence  Providence  CCRI Liston Campus ROOFTOP
# 33847  Rhode Island  Providence  Providence  CCRI Liston Campus ROOFTOP
# 33848  Rhode Island  Providence  Providence  CCRI Liston Campus ROOFTOP
# 33849  Rhode Island  Providence  Providence  CCRI Liston Campus ROOFTOP
#
#                           Address           MSA or CBSA Name    Data Source
# 0      1 Hilton St, PROVIDENCE RI  Providence-Warwick, RI-MA  AQS Data Mart
# 1      1 Hilton St, PROVIDENCE RI  Providence-Warwick, RI-MA  AQS Data Mart
# 2      1 Hilton St, PROVIDENCE RI  Providence-Warwick, RI-MA  AQS Data Mart
# 3      1 Hilton St, PROVIDENCE RI  Providence-Warwick, RI-MA  AQS Data Mart
# 4      1 Hilton St, PROVIDENCE RI  Providence-Warwick, RI-MA  AQS Data Mart
# ...                           ...                        ...            ...
# 33845  1 Hilton St, PROVIDENCE RI  Providence-Warwick, RI-MA  AQS Data Mart
# 33846  1 Hilton St, PROVIDENCE RI  Providence-Warwick, RI-MA  AQS Data Mart
# 33847  1 Hilton St, PROVIDENCE RI  Providence-Warwick, RI-MA  AQS Data Mart
# 33848  1 Hilton St, PROVIDENCE RI  Providence-Warwick, RI-MA  AQS Data Mart
# 33849  1 Hilton St, PROVIDENCE RI  Providence-Warwick, RI-MA  AQS Data Mart
#
# [33850 rows x 7 columns]

# %%
df_data['Parameter Name'].unique()
# Out:
# <StringArray>
# [        'PM2.5 - Local Conditions',       'Wind Direction - Resultant',
#            'Black carbon PM2.5 STP',        'Std Dev Vt Wind Direction',
#      'Particle Number, Total Count',                'Relative Humidity',
#               'Outdoor Temperature',           'Wind Speed - Resultant',
#                 'Chromium PM10 STP',                    'Lead PM10 STP',
#             'PM10 Total 0-10um STP',           '1,3,5-Trimethylbenzene',
#            '1,2,4-Trimethylbenzene',                          'Styrene',
#                        'm/p Xylene',                          'Benzene',
#                           'Toluene',                         'o-Xylene',
#                       'Cyclohexane',           '2,2,4-Trimethylpentane',
#                      'Formaldehyde',                     'Acetaldehyde',
#                         'n-Pentane',                         'n-Hexane',
#                         'n-Heptane',                         'n-Octane',
#                'Ethylene dibromide',                    'Chlorobenzene',
#         '1,1,2,2-Tetrachloroethane',                         'n-Butane',
#               'Ethylene dichloride',              '1,2-Dichloropropane',
#           'cis-1,3-Dichloropropene',        'trans-1,3-Dichloropropene',
#                    'Vinyl chloride',                    'Acrylonitrile',
#              '1,1-Dichloroethylene',               '1,1-Dichloroethane',
#                        'Chloroform',                'Trichloroethylene',
#               'Tetrachloroethylene',              '1,4-Dichlorobenzene',
#              'Carbon tetrachloride',                    'alpha.-Pinene',
#                    'Ethylene oxide',                  'Dichloromethane',
#                     '1,3-Butadiene',          'Methyl tert-butyl ether',
#            '1,2,4-Trichlorobenzene',                      'Naphthalene',
#                         'Bromoform',            '1,1,2-Trichloroethane',
#        'trans-1,2-Dichloroethylene',        '1,1,1,2-Tetrachloroethane',
#               '1,3-Dichlorobenzene',              '1,2-Dichlorobenzene',
#                      'Chloroethane',           'Trichlorofluoromethane',
#               'Methyl ethyl ketone',                'Methyl chloroform',
#               'Acrolein - Verified',                    'Chloromethane',
#                  'Cadmium PM10 STP',               'Manganese PM10 STP',
#                   'Nickel PM10 STP',                 'Arsenic PM10 STP',
#                      'Ethylbenzene',               'Beryllium PM10 STP',
#                           'Acetone', 'Indeno[1,2,3-cd]pyrene (TSP) STP',
#    'Benzo[k]fluoranthene (TSP) STP',         'Benzo[e]pyrene (TSP) STP',
#  'Dibenzo[a,h]anthracene (TSP) STP',   'Benzo[g,h,i]perylene (TSP) STP',
#          'Benzo[a]pyrene (TSP) STP',                 'Pyrene (TSP) STP',
#                'Coronene (TSP) STP',               'Perylene (TSP) STP',
#      'Benzo[a]anthracene (TSP) STP',   'Benzo[b]fluoranthene (TSP) STP',
#          'Acenaphthylene (TSP) STP',               'Fluorene (TSP) STP',
#            'Phenanthrene (TSP) STP',             'Anthracene (TSP) STP',
#            'Fluoranthene (TSP) STP',                     'Benzaldehyde',
#                 'Antimony PM10 STP',            'Naphthalene (TSP) STP',
#            'Acenaphthene (TSP) STP',                     'Bromomethane',
#                     'Butyl benzene',               'Chrysene (TSP) STP']
# Length: 92, dtype: str

# %%
df_data.nunique()
# Out:
# State Code                       1
# County Code                      1
# Site Number                      1
# Parameter Code                  92
# POC                              6
# Latitude                         1
# Longitude                        1
# Datum                            1
# Parameter Name                  92
# Duration Description             3
# Pollutant Standard               3
# Date (Local)                  1502
# Year                             5
# Day In Year (Local)            366
# Units of Measure                 9
# Exceptional Data Type            0
# Nonreg Observation Count         0
# Observation Count               19
# Observation Percent             18
# Nonreg Arithmetic Mean           0
# Arithmetic Mean               6883
# Nonreg First Maximum Value       0
# First Maximum Value           2371
# First Maximum Hour              24
# AQI                             83
# Daily Criteria Indicator         2
# Tribe Name                       0
# State Name                       1
# County Name                      1
# City Name                        1
# Local Site Name                  1
# Address                          1
# MSA or CBSA Name                 1
# Data Source                      1
# dtype: int64

# %%
df_data.describe()
# Out:
#        State Code  County Code  Site Number  Parameter Code           POC  \
# count     33850.0      33850.0      33850.0    33850.000000  33850.000000
# mean         44.0          7.0         22.0    55757.373589      2.422718
# std           0.0          0.0          0.0    21865.302910      1.667990
# min          44.0          7.0         22.0    17141.000000      1.000000
# 25%          44.0          7.0         22.0    43801.000000      1.000000
# 50%          44.0          7.0         22.0    45810.000000      2.000000
# 75%          44.0          7.0         22.0    82102.000000      3.000000
# max          44.0          7.0         22.0    88101.000000      7.000000
#
#            Latitude     Longitude          Year  Day In Year (Local)  \
# count  3.385000e+04  33850.000000  33850.000000         33850.000000
# mean   4.180747e+01    -71.412968   2023.497134           178.539764
# std    7.105532e-15      0.000000      1.130711           106.463960
# min    4.180747e+01    -71.412968   2022.000000             1.000000
# 25%    4.180747e+01    -71.412968   2022.000000            85.000000
# 50%    4.180747e+01    -71.412968   2023.000000           178.000000
# 75%    4.180747e+01    -71.412968   2024.000000           271.000000
# max    4.180747e+01    -71.412968   2026.000000           366.000000
#
#        Exceptional Data Type  Nonreg Observation Count  Observation Count  \
# count                    0.0                       0.0       33850.000000
# mean                     NaN                       NaN           8.250251
# std                      NaN                       NaN          10.664812
# min                      NaN                       NaN           1.000000
# 25%                      NaN                       NaN           1.000000
# 50%                      NaN                       NaN           1.000000
# 75%                      NaN                       NaN          24.000000
# max                      NaN                       NaN          24.000000
#
#        Observation Percent  Nonreg Arithmetic Mean  Arithmetic Mean  \
# count         33850.000000                     0.0     33850.000000
# mean             99.858316                     NaN        96.034701
# std               2.400088                     NaN       854.898806
# min              25.000000                     NaN        -1.375000
# 25%             100.000000                     NaN         0.032000
# 50%             100.000000                     NaN         0.671500
# 75%             100.000000                     NaN         6.800000
# max             100.000000                     NaN     32061.416667
#
#        Nonreg First Maximum Value  First Maximum Value  First Maximum Hour  \
# count                         0.0         33850.000000        33850.000000
# mean                          NaN           185.384981            3.471462
# std                           NaN          1789.719518            6.435808
# min                           NaN            -1.300000            0.000000
# 25%                           NaN             0.032000            0.000000
# 50%                           NaN             0.800000            0.000000
# 75%                           NaN             9.000000            4.000000
# max                           NaN         55558.000000           23.000000
#
#        Tribe Name
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %% [markdown]
# Questions
# 1. What is the structure of the data?
# 2. What are the data types of the columns?
# 3.
# 4. Do we need all the columns?
# 6 How many unique values are there in each column?
# 5. Do we need all the rows?
